# %%
from scipy.io import loadmat
import project_path as pp
import os
from matplotlib import pyplot as plt
import cv2
import csv
from dataloader import DataBatcher
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
db = DataBatcher(type=DataBatcher.TRAIN)
X, Y = db[0]

# %%
record = np.random.randint(0, len(X))
right_eye = X[record][0]
left_eye = X[record][1]
face = X[record][2]
face_grid = X[record][3]

# %%
plt.imshow(cv2.cvtColor(right_eye, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(left_eye, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(face, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(np.reshape(face_grid, newshape=(25, 25)), cmap='gray')
